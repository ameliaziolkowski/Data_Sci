# %% [markdown]
# <a href="https://colab.research.google.com/github/ameliaziolkowski/Data_Sci/blob/main/Ziolkowski_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
from skimage.io import imread

# %%
from skimage.transform import resize

# %%
url = 'https://raw.githubusercontent.com/ameliaziolkowski/Data_Sci/main/data%20set/train/italy/italy/1.jpg'

# %%
im = imread(url)

# %%
im.shape
# Out:
# (168, 300, 3)

# %%
plt.figure(figsize=(20,10))   #figsize changes the size of the picture
plt.imshow(im);
plt.axis('off')
# Out:
# (-0.5, 299.5, 167.5, -0.5)

# %%
im.reshape(-1)
# Out:
# array([222, 200, 212, ...,  93,  94,  37], dtype=uint8)

# %%
im
# Out:
# array([[[222, 200, 212],
#         [222, 200, 212],
#         [223, 201, 213],
#         ...,
#         [246, 230, 207],
#         [246, 230, 207],
#         [246, 230, 207]],
#
#        [[220, 198, 210],
#         [220, 198, 210],
#         [221, 200, 209],
#         ...,
#         [253, 237, 214],
#         [253, 237, 214],
#         [253, 237, 214]],
#
#        [[217, 196, 205],
#         [217, 196, 205],
#         [218, 197, 206],
#         ...,
#         [255, 244, 221],
#         [255, 244, 221],
#         [255, 244, 221]],
#
#        ...,
#
#        [[ 93,  78,   0],
#         [120, 105,  14],
#         [101,  86,   0],
#         ...,
#         [100, 108,  49],
#         [101, 108,  54],
#         [101, 108,  56]],
#
#        [[103,  88,   0],
#         [150, 135,  44],
#         [128, 113,  22],
#         ...,
#         [ 99, 103,  42],
#         [ 99, 102,  45],
#         [ 99, 102,  47]],
#
#        [[134, 119,  28],
#         [125, 110,  19],
#         [144, 129,  38],
# ...

# %%
im_flattened = im.reshape

# %%
plt.imshow(im);

# %%
plt.imshow(im[:,:,0])

# %%
plt.imshow(im[10:50,:,0])   #this crops the image horizontally

# %%
plt.imshow(im[:,100:200,:])     #this crops the image vertically

# %%
plt.imshow(im[:,120:240,:])

# %%
plt.imshow(im[:,240:300,:])
